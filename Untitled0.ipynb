# %%
x=5
y="john"
print(x)
print(y)
# Out:
# 5
# john

# %%
x=4
x="Sally"
x=8
print(x)
# Out:
# 8

# %%
x=str(3)
y=int(3)
z=float(3)
print(x)
print(y)
print(z)
# Out:
# 3
# 3
# 3.0

# %%
x=5
y="john"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a=4
A="Sally"
print(a)
print(A)
# Out:
# 4
# Sally

# %%
x,y,z+"Orange","banana","cherry"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1555368390.py in <cell line: 0>()
# ----> 1 x,y,z+"Orange","banana","cherry"
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
x,y,z="Orange","banana","cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# banana
# cherry

# %%
x=y=z="Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %%
fruits=["apple","banana","cherry"]
x,y,z=fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %%
x="python"
y="is"
z="awersome"
print(x,y,z)
# Out:
# python is awersome

# %%
x=5
print(type(x))
print(x)
# Out:
# <class 'int'>
# 5

# %%
x=1
y=2.8
z=1j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
x=1
y=35656222554887711
z=-3255522
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x=1.10
y=1.0
z=-35.59
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x=3+5j
y=5j
z=-5j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
x=1
y=2.8
z=1j
a=float(x)
b=int(y)
c=complex(x)
print(a)
print(b)
print(c)
# Out:
# 1.0
# 2
# (1+0j)

# %%
x=int(1)
y=int(2.8)
z=int("3")
print(x)
print(y)
print(z)
# Out:
# 1
# 2
# 3

# %%
x=float(1)
y=float(2.8)
z=float("3")
w=float("4.2")
print(x)
print(y)
print(z)
print(w)
# Out:
# 1.0
# 2.8
# 3.0
# 4.2

# %%
x=str("s1")
y=str(2)
z=str(3.0)
print(x)
print(y)
print(z)
# Out:
# s1
# 2
# 3.0

# %%
a="Hello"
print(a)
# Out:
# Hello

# %%
a="""Lorem ipsum dolor sit amet,consectetur adipiscing." ""
# Out:
#   File "/tmp/ipython-input-1401884911.py", line 1
#     a="""Lorem ipsum dolor sit amet,consectetur adipiscing." ""
#       ^
# SyntaxError: incomplete input

# %%
a="""Lorem ipsum dolor sit amet,consectetur adipiscing elit,sed do eiusmod tempor incididunt ut labore et dolore magna aliqua."""
print(a)
# Out:
# Lorem ipsum dolor sit amet,consectetur adipiscing elit,sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.

# %%
a="Hello, world!"
print(a[1])
# Out:
# e

# %%
for x in "banana":
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
a= 'hello'
print(a)
# Out:
# hello

# %%
a= I'm  Haaniyah
print(a)
# Out:
#   File "/tmp/ipython-input-427342250.py", line 1
#     a= I'm  Haaniyah
#         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
a="Hello, World!"
print(len(a))
# Out:
# 13

# %%
txt="The best things in life are free !"
print("free" in txt)
# Out:
# True

# %%
txt="The best things in life are free!"
if"free"in txt:
  print("Yes,'free'is present")
# Out:
# Yes,'free'is present

# %%
txt="The best things in life are free!"
print("expensive" not in txt)
# Out:
# True

# %%
b="Hello, World!"
print(b[2:5])
# Out:
# llo

# %%
a=b="Hello, World!"
print(b[:5])
print(b[2:])
print(b[-5:-2])
print(a.upper())
print(a.lower)
# Out:
# Hello
# llo, World!
# orl
# HELLO, WORLD!
# <built-in method lower of str object at 0x7eb0c7e87bb0>

# %%
a=" Hello, World!"
print(len(a))
print(a.strip())
print(a.replace("H","J"))
print(a.split(","))
# Out:
# 14
# Hello, World!
#  Jello, World!
# [' Hello', ' World!']

# %%
a="Hello"
b="World"
c=a + b
print(c)
# Out:
# HelloWorld

# %%
print(10>9)
print(10==9)
print(10<9)
# Out:
# True
# False
# False

# %%
a=200
b=33
if b>a:
  print("b is greatest than a")
else:
  print("b is not greatest")
# Out:
# b is not greatest

# %%
print(bool("Hello"))
print(bool(15))
# Out:
# True
# True

# %%
mylist=["apple","banana","cherry"]
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist=["apple","banana","cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist=["apple","banana","cherry","apple","cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'cherry']

# %%
thislist=["apple","banana","cherry"]
print(len(thislist))
# Out:
# 3

# %%
list1=["apple","banana","cherry"]
list2=[1,5,7,9,3]
list3=[True,False,False]
print(list1)
print(list2)
print(list3)
# Out:
# ['apple', 'banana', 'cherry']
# [1, 5, 7, 9, 3]
# [True, False, False]

# %%
list1=["abc",34, True, 40, "male"]
print(list1)
# Out:
# ['abc', 34, True, 40, 'male']

# %%
thislist=list(("apple","banana","cherry","orange","kiwi","melon","mango"))
print(thislist[1])
print(thislist[-1])
print(thislist[2:5])
print(thislist[:4])
print(thislist[-4:-1])
# Out:
# banana
# mango
# ['cherry', 'orange', 'kiwi']
# ['apple', 'banana', 'cherry', 'orange']
# ['orange', 'kiwi', 'melon']

# %%
thislist=["apple","banana","cherry"]
thislist.append("orange")
print(thislist)
thislist.insert(1, "orange")
print(thislist)
thislist.remove("banana")
print(thislist)
for x in range(len(thislist)):
  print(thislist[i])
# Out:
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'orange', 'banana', 'cherry', 'orange']
# ['apple', 'orange', 'cherry', 'orange']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-988259767.py in <cell line: 0>()
#       7 print(thislist)
#       8 for x in range(len(thislist)):
# ----> 9   print(thislist[i])
#
# NameError: name 'i' is not defined

# %%
thislist=["apple","banana","cherry"]
thislist.append("orange")
print(thislist)
thislist.insert(1, "orange")
print(thislist)
thislist.remove("banana")
print(thislist)
for x in range(len(thislist)):
  print(x)
  for i in range(len(thislist)):
    print(thislist[i])
# Out:
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'orange', 'banana', 'cherry', 'orange']
# ['apple', 'orange', 'cherry', 'orange']
# 0
# apple
# orange
# cherry
# orange
# 1
# apple
# orange
# cherry
# orange
# 2
# apple
# orange
# cherry
# orange
# 3
# apple
# orange
# cherry
# orange

# %%
mytuple=("apple","banana","cherry")
thistuple=("apple","banana","cherry")
print(thistuple)
print(thistuple[-1])
print(thistuple[1])
# Out:
# ('apple', 'banana', 'cherry')
# cherry
# banana

# %%
thistuple=("apple","banana","cherry","orange","kiwi","melon","mango")
print(thistuple[:4])
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
myset={"apple","banana","cherry"}
thisset={"apple","banana","cherry"}
print(thisset)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
thisset{"apple","banana","cherry",True,1,2}
print(thisset)
thisset=("apple","banana","cherry")
print(thisset)
# Out:
#   File "/tmp/ipython-input-829449098.py", line 1
#     thisset{"apple","banana","cherry",True,1,2}
#            ^
# SyntaxError: invalid syntax

# %%
thisset={"apple","banana","cherry",True,1,2}
print(thisset)
thisset=("apple","banana","cherry")
print(thisset)
# Out:
# {True, 'cherry', 2, 'banana', 'apple'}
# ('apple', 'banana', 'cherry')

# %%
set1={"apple","banana","cherry",True,1,2}
set2={1,5,7,9,3}
set3={True,False,False}
print(set1)
print(set2)
print(set3)
# Out:
# {True, 'cherry', 2, 'banana', 'apple'}
# {1, 3, 5, 7, 9}
# {False, True}

# %%
set1={"abc,34,True,40,male"}
print(set1)
# Out:
# {'abc,34,True,40,male'}

# %%
thisset={"apple","banana","cherry"}
for x in thisset:
  print(x)
# Out:
# cherry
# banana
# apple

# %%
set1={"a","b","c"}
set2={1,2,3}
set3=set1.union(set2)
print(set3)
# Out:
# {1, 2, 'b', 3, 'a', 'c'}

# %%
set1={"a","b","c"}
set2={1,2,3}
set3=set1|set2
print(set3)
# Out:
# {1, 2, 'b', 3, 'a', 'c'}

# %%
set1={}
